# %% [markdown]
# ## Apply an image-based profiling pipeline using pycytominer
#
# As described fully in [Caicedo et al. 2017](https://doi.org/10.1038/nmeth.4397), an image-based profiling pipeline consists of three core steps:
#
# 1. Aggregation
# 2. Normalization
# 3. Feature selection
#
# [Pycytominer](https://github.com/cytomining/pycytominer) is a python package, built on top of pandas, that facilitates all of these steps and more.
#
# ### Data levels
#
# The concept of "data levels" is important to understand when implementing an image-based profiling pipeline.
#
# | Data | Level |
# | :---- | :---- |
# | Images | Level 1 |
# | Single cell profiles (SQLite) | Level 2 |
# | Aggregated profiles with metadata information | Level 3 |
# | Normalized aggregated profiles | Level 4a |
# | Normalized and feature selected profiles | Level 4b |
# | Consensus profiles | Level 5 |

# %%
import pathlib
import pandas as pd

from pycytominer import annotate, normalize, feature_select, consensus
from pycytominer.cyto_utils import cells

# %% [markdown]
# ### Step 0 - Initialize data and options

# %%
data_dir = "data"
plate_id = "218360"
platemap = f"{plate_id}.txt"

sqlite_file = f"sqlite:///{data_dir}/{plate_id}.sqlite"
sqlite_file
# Out:
# 'sqlite:///data/218360.sqlite'

# %%
output_dir = pathlib.Path("profiles")
output_dir.mkdir(exist_ok=True)

# %%
# Load platemap file
platemap_file = pathlib.Path(f"{data_dir}/{platemap}")
platemap_df = pd.read_csv(platemap_file, sep="\t")

print(platemap_df.shape)
platemap_df.head(3)
# Out:
# (60, 8)
#    plate_map_name well_position clone_number  plate_ID     plate_filename  \
# 0          218360           B02  WT parental    218360  20200626-WTpAE-Lo
# 1          218360           B03  WT parental    218360  20200626-WTpAE-Lo
# 2          218360           B04  WT parental    218360  20200626-WTpAE-Lo
#
#            treatment treatment_time         cell_density
# 0          0.1% DMSO          13 hr  2.5x10^3 cells/well
# 1  2.1 nM bortezomib          13 hr  2.5x10^3 cells/well
# 2   21 nM bortezomib          13 hr  2.5x10^3 cells/well

# %%
# Output options
compression_options = {"method": "gzip", "mtime": 1}

# %% [markdown]
# ### Step 1 - Single cell aggregation
#
# In this step, **level 2 profiles** (single cells) are processed to **level 3 profiles** (well-level profiles).

# %%
# Initialize the single cells class
sc_data = cells.SingleCells(
    sqlite_file,
    strata=["Metadata_Plate", "Metadata_Well"],
    features="infer",
    compartments=["cells", "cytoplasm", "nuclei"],
    merge_cols=["TableNumber", "ImageNumber"],
    aggregation_operation="median",
    load_image_data=True,
    subsample_frac=1,
    subsample_n="all",
    subsampling_random_state="none"
)

# %%
# Count cells
cell_count_df = sc_data.count_cells()

cell_count_df = (
    cell_count_df.merge(
        platemap_df,
        left_on="Metadata_Well",
        right_on="well_position"
    )
)

# Output cell count to file
cell_count_file = pathlib.Path(f"{output_dir}/cell_counts.tsv")
cell_count_df.to_csv(cell_count_file, sep="\t", index=False)

print(cell_count_df.shape)
cell_count_df.head()
# Out:
# (60, 11)
#    Metadata_Plate Metadata_Well  cell_count  plate_map_name well_position  \
# 0          218360           B02        1386          218360           B02
# 1          218360           B03         793          218360           B03
# 2          218360           B04         456          218360           B04
# 3          218360           B05         258          218360           B05
# 4          218360           B06        1094          218360           B06
#
#   clone_number  plate_ID     plate_filename          treatment treatment_time  \
# 0  WT parental    218360  20200626-WTpAE-Lo          0.1% DMSO          13 hr
# 1  WT parental    218360  20200626-WTpAE-Lo  2.1 nM bortezomib          13 hr
# 2  WT parental    218360  20200626-WTpAE-Lo   21 nM bortezomib          13 hr
# 3  WT parental    218360  20200626-WTpAE-Lo  210 nM bortezomib          13 hr
# 4  WT parental    218360  20200626-WTpAE-Lo          0.1% DMSO          13 hr
#
#           cell_density
# 0  2.5x10^3 cells/well
# 1  2.5x10^3 cells/well
# 2  2.5x10^3 cells/well
# 3  2.5x10^3 cells/well
# 4  2.5x10^3 cells/well

# %%
# Perform the aggregation - output well level profiles
output_file = pathlib.Path(f"{output_dir}/{plate_id}.csv.gz")

# Aggregate profiles can output a file, or save the result to a variable
# Here, we output the intermediate result to a file
sc_data.aggregate_profiles(
    output_file=output_file,
    compute_subsample=True,
    compression_options=compression_options,
    float_format=None
)
# Out:
# PosixPath('profiles/218360.csv.gz')

# %%
# Read in and preview what was output in the previous step
# Note: This is not necessary to perform in automated pipelines, but is a nice check.
aggregated_df = pd.read_csv(output_file)

print(aggregated_df.shape)
aggregated_df.head(3)
# Out:
# (60, 3530)
#    Metadata_Plate Metadata_Well  Metadata_Site_Count  Metadata_Object_Count  \
# 0          218360           B02                   16                   1386
# 1          218360           B03                   16                    793
# 2          218360           B04                   16                    456
#
#    Cells_AreaShape_Area  Cells_AreaShape_Center_X  Cells_AreaShape_Center_Y  \
# 0                3103.0                    1185.5                    1134.5
# 1                3365.0                    1067.0                    1137.0
# 2                3360.5                    1141.0                    1166.5
#
#    Cells_AreaShape_Center_Z  Cells_AreaShape_Compactness  \
# 0                       1.0                     1.176543
# 1                       1.0                     1.148519
# 2                       1.0                     1.152265
#
#    Cells_AreaShape_Eccentricity  ...  Nuclei_Texture_Variance_RNA_10_02  \
# 0                      0.762628  ...                         134.630929
# 1                      0.738471  ...                         143.936790
# 2                      0.735413  ...                         139.837458
#
#    Nuclei_Texture_Variance_RNA_10_03  Nuclei_Texture_Variance_RNA_20_00  \
# 0                         136.168955                         130.178186
# 1                         150.720200                         155.195390
# 2                         147.532470                         143.564510
#
#    Nuclei_Texture_Variance_RNA_20_01  Nuclei_Texture_Variance_RNA_20_02  \
# 0                         143.230289                         130.452067
# 1                         182.867025                         153.439750
# 2                         152.944447                         143.430507
#
#    Nuclei_Texture_Variance_RNA_20_03  Nuclei_Texture_Variance_RNA_5_00  \
# 0                         139.230146                        135.932245
# 1                         162.839254                        146.040203
# 2                         147.967005                        140.323478
#
#    Nuclei_Texture_Variance_RNA_5_01  Nuclei_Texture_Variance_RNA_5_02  \
# 0                        133.168297                        137.391985
# 1                        143.993466                        147.316124
# 2                        141.193128                        140.788792
#
#    Nuclei_Texture_Variance_RNA_5_03
# 0                        135.095233
# 1                        147.909953
# 2                        140.561236
#
# [3 rows x 3530 columns]

# %% [markdown]
# ## Step 2 - Annotate wells using the platemap file
#
# In this step, **level 3 profiles** (well-level profiles) are annotated with platemap metadata.

# %%
# Annotate profiles
annotate_file = pathlib.Path(f"{output_dir}/{plate_id}_augmented.csv.gz")

annotate(
    profiles=output_file,
    platemap=platemap_df,
    join_on=["Metadata_well_position", "Metadata_Well"],
    output_file=annotate_file,
    compression_options=compression_options,
)

# %%
# Read in and preview what was output in the previous step 
annotated_df = pd.read_csv(annotate_file)

print(annotated_df.shape)
annotated_df.head(3)
# Out:
# (60, 3537)
#    Metadata_plate_map_name Metadata_clone_number  Metadata_plate_ID  \
# 0                   218360           WT parental             218360
# 1                   218360           WT parental             218360
# 2                   218360           WT parental             218360
#
#   Metadata_plate_filename Metadata_treatment Metadata_treatment_time  \
# 0       20200626-WTpAE-Lo          0.1% DMSO                   13 hr
# 1       20200626-WTpAE-Lo  2.1 nM bortezomib                   13 hr
# 2       20200626-WTpAE-Lo   21 nM bortezomib                   13 hr
#
#   Metadata_cell_density  Metadata_Plate Metadata_Well  Metadata_Site_Count  \
# 0   2.5x10^3 cells/well          218360           B02                   16
# 1   2.5x10^3 cells/well          218360           B03                   16
# 2   2.5x10^3 cells/well          218360           B04                   16
#
#    ...  Nuclei_Texture_Variance_RNA_10_02  Nuclei_Texture_Variance_RNA_10_03  \
# 0  ...                         134.630929                         136.168955
# 1  ...                         143.936790                         150.720200
# 2  ...                         139.837458                         147.532470
#
#    Nuclei_Texture_Variance_RNA_20_00  Nuclei_Texture_Variance_RNA_20_01  \
# 0                         130.178186                         143.230289
# 1                         155.195390                         182.867025
# 2                         143.564510                         152.944447
#
#    Nuclei_Texture_Variance_RNA_20_02  Nuclei_Texture_Variance_RNA_20_03  \
# 0                         130.452067                         139.230146
# 1                         153.439750                         162.839254
# 2                         143.430507                         147.967005
#
#    Nuclei_Texture_Variance_RNA_5_00  Nuclei_Texture_Variance_RNA_5_01  \
# 0                        135.932245                        133.168297
# 1                        146.040203                        143.993466
# 2                        140.323478                        141.193128
#
#    Nuclei_Texture_Variance_RNA_5_02  Nuclei_Texture_Variance_RNA_5_03
# 0                        137.391985                        135.095233
# 1                        147.316124                        147.909953
# 2                        140.788792                        140.561236
#
# [3 rows x 3537 columns]

# %% [markdown]
# ## Step 3 - Normalize well-level profiles
#
# In this step, **level 3 profiles** (well-level profiles) are normalized to form **level 4a profiles**.

# %%
# Normalize profiles
normalize_file = pathlib.Path(f"{output_dir}/{plate_id}_normalized.csv.gz")

normalize(
    profiles=annotate_file,
    features="infer",
    meta_features="infer",
    samples="Metadata_treatment == '0.1% DMSO'",
    method="standardize",
    output_file=normalize_file,
    compression_options=compression_options,
)

# %%
# Read in and preview what was output in the previous step 
normalized_df = pd.read_csv(normalize_file)

print(normalized_df.shape)
normalized_df.head(3)
# Out:
# (60, 3537)
#    Metadata_plate_map_name Metadata_clone_number  Metadata_plate_ID  \
# 0                   218360           WT parental             218360
# 1                   218360           WT parental             218360
# 2                   218360           WT parental             218360
#
#   Metadata_plate_filename Metadata_treatment Metadata_treatment_time  \
# 0       20200626-WTpAE-Lo          0.1% DMSO                   13 hr
# 1       20200626-WTpAE-Lo  2.1 nM bortezomib                   13 hr
# 2       20200626-WTpAE-Lo   21 nM bortezomib                   13 hr
#
#   Metadata_cell_density  Metadata_Plate Metadata_Well  Metadata_Site_Count  \
# 0   2.5x10^3 cells/well          218360           B02                   16
# 1   2.5x10^3 cells/well          218360           B03                   16
# 2   2.5x10^3 cells/well          218360           B04                   16
#
#    ...  Nuclei_Texture_Variance_RNA_10_02  Nuclei_Texture_Variance_RNA_10_03  \
# 0  ...                           1.994853                           1.918636
# 1  ...                           2.343617                           2.448316
# 2  ...                           2.189983                           2.332280
#
#    Nuclei_Texture_Variance_RNA_20_00  Nuclei_Texture_Variance_RNA_20_01  \
# 0                           2.082421                           1.807392
# 1                           3.071418                           3.091680
# 2                           2.611618                           2.122145
#
#    Nuclei_Texture_Variance_RNA_20_02  Nuclei_Texture_Variance_RNA_20_03  \
# 0                           2.111036                           2.086668
# 1                           3.011963                           2.951846
# 2                           2.619684                           2.406839
#
#    Nuclei_Texture_Variance_RNA_5_00  Nuclei_Texture_Variance_RNA_5_01  \
# 0                          1.950899                          1.943007
# 1                          2.326277                          2.351921
# 2                          2.113976                          2.246140
#
#    Nuclei_Texture_Variance_RNA_5_02  Nuclei_Texture_Variance_RNA_5_03
# 0                          1.988028                          1.987186
# 1                          2.354838                          2.466231
# 2                          2.113579                          2.191518
#
# [3 rows x 3537 columns]

# %% [markdown]
# ## Step 4 - Apply feature selection
#
# In this step, we apply a series of feature selection steps to **level 4a profiles** (normalized well-level profiles) to form **level 4b profiles**.

# %%
# Apply feature selection
feature_select_file = pathlib.Path(f"{output_dir}/{plate_id}_normalized_feature_select.csv.gz")

feature_select_opts = [
    "variance_threshold",
    "drop_na_columns",
    "correlation_threshold",
    "blocklist",
    "drop_outliers"
]

feature_select(
    profiles=normalize_file,
    features="infer",
    samples="all",
    operation=feature_select_opts,
    output_file=feature_select_file,
    compression_options=compression_options,
)

# %%
# Read in and preview what was output in the previous step 
feature_select_df = pd.read_csv(feature_select_file)

print(feature_select_df.shape)
feature_select_df.head(3)
# Out:
# (60, 401)
#    Metadata_plate_map_name Metadata_clone_number  Metadata_plate_ID  \
# 0                   218360           WT parental             218360
# 1                   218360           WT parental             218360
# 2                   218360           WT parental             218360
#
#   Metadata_plate_filename Metadata_treatment Metadata_treatment_time  \
# 0       20200626-WTpAE-Lo          0.1% DMSO                   13 hr
# 1       20200626-WTpAE-Lo  2.1 nM bortezomib                   13 hr
# 2       20200626-WTpAE-Lo   21 nM bortezomib                   13 hr
#
#   Metadata_cell_density  Metadata_Plate Metadata_Well  Metadata_Site_Count  \
# 0   2.5x10^3 cells/well          218360           B02                   16
# 1   2.5x10^3 cells/well          218360           B03                   16
# 2   2.5x10^3 cells/well          218360           B04                   16
#
#    ...  Nuclei_Texture_InfoMeas2_Mito_20_03  \
# 0  ...                             0.666380
# 1  ...                             1.022193
# 2  ...                             1.378143
#
#    Nuclei_Texture_InfoMeas2_RNA_5_02  \
# 0                           1.640270
# 1                           0.938770
# 2                           0.603039
#
#    Nuclei_Texture_InverseDifferenceMoment_AGP_20_01  \
# 0                                         -1.123220
# 1                                         -0.321421
# 2                                         -0.322174
#
#    Nuclei_Texture_InverseDifferenceMoment_DNA_20_03  \
# 0                                         -0.511368
# 1                                         -1.862488
# 2                                         -2.405300
#
#    Nuclei_Texture_InverseDifferenceMoment_ER_20_03  \
# 0                                        -1.301264
# 1                                        -0.175040
# 2                                         0.392906
#
#    Nuclei_Texture_InverseDifferenceMoment_Mito_20_03  \
# 0                                          -0.172448
# 1                                           0.309052
# 2                                          -1.128065
#
#    Nuclei_Texture_InverseDifferenceMoment_RNA_20_00  \
# 0                                         -1.220708
# 1                                         -0.832363
# 2                                         -0.716326
#
#    Nuclei_Texture_SumVariance_ER_5_01  Nuclei_Texture_SumVariance_Mito_10_00  \
# 0                            1.750259                               0.405271
# 1                            2.854113                               2.696279
# 2                            1.869677                               8.215960
#
#    Nuclei_Texture_SumVariance_RNA_10_02
# 0                              1.982705
# 1                              2.137837
# 2                              1.554196
#
# [3 rows x 401 columns]

# %% [markdown]
# ## Step 5 - Form consensus signatures
#
# In this step, we collapse replicates (**level 4 profiles**) into a single profile.
# This forms **level 5 profiles**.

# %%
# Generate consensus profiles
consensus_file = pathlib.Path(f"{output_dir}/{plate_id}_consensus.csv.gz")

consensus(
    profiles=feature_select_df,
    replicate_columns=["Metadata_clone_number", "Metadata_treatment"],
    operation="modz",
    features="infer",
    output_file=consensus_file,
    modz_args={
        "method": "spearman",
        "min_weight": 0.01,
        "precision": 4,
    },
    compression_options=compression_options,
)

# %%
# Read in and preview what was output in the previous step 
consensus_df = pd.read_csv(consensus_file)

print(consensus_df.shape)
consensus_df.head(3)
# Out:
# (12, 392)
#   Metadata_clone_number Metadata_treatment  Cells_AreaShape_FormFactor  \
# 0               Clone A          0.1% DMSO                   -0.012822
# 1               Clone A  2.1 nM bortezomib                   -1.800890
# 2               Clone A   21 nM bortezomib                   -3.368059
#
#    Cells_AreaShape_Orientation  Cells_AreaShape_Zernike_0_0  \
# 0                     0.039280                    -0.943973
# 1                    -0.281891                    -1.001484
# 2                    -0.130583                    -1.832667
#
#    Cells_AreaShape_Zernike_1_1  Cells_AreaShape_Zernike_2_0  \
# 0                    -0.571392                    -0.719932
# 1                    -0.746903                    -0.355596
# 2                    -0.117159                     0.443206
#
#    Cells_AreaShape_Zernike_3_1  Cells_AreaShape_Zernike_3_3  \
# 0                     0.448598                     0.672615
# 1                     0.241331                    -0.811865
# 2                     1.054792                    -3.051336
#
#    Cells_AreaShape_Zernike_4_0  ...  Nuclei_Texture_InfoMeas2_Mito_20_03  \
# 0                     0.166382  ...                            -0.022600
# 1                     0.549042  ...                             0.471521
# 2                     1.910167  ...                             1.247188
#
#    Nuclei_Texture_InfoMeas2_RNA_5_02  \
# 0                          -0.544882
# 1                          -0.615206
# 2                          -0.767633
#
#    Nuclei_Texture_InverseDifferenceMoment_AGP_20_01  \
# 0                                          1.048027
# 1                                          0.592792
# 2                                          0.969311
#
#    Nuclei_Texture_InverseDifferenceMoment_DNA_20_03  \
# 0                                          0.717373
# 1                                         -0.401117
# 2                                         -1.975002
#
#    Nuclei_Texture_InverseDifferenceMoment_ER_20_03  \
# 0                                         0.690795
# 1                                         0.165698
# 2                                         0.059089
#
#    Nuclei_Texture_InverseDifferenceMoment_Mito_20_03  \
# 0                                           0.403234
# 1                                          -0.366404
# 2                                          -1.450205
#
#    Nuclei_Texture_InverseDifferenceMoment_RNA_20_00  \
# 0                                          0.838370
# 1                                          0.488193
# 2                                          0.349720
#
#    Nuclei_Texture_SumVariance_ER_5_01  Nuclei_Texture_SumVariance_Mito_10_00  \
# 0                           -0.635526                               0.061329
# 1                           -0.067002                               0.768437
# 2                            2.162809                               6.807487
#
#    Nuclei_Texture_SumVariance_RNA_10_02
# 0                             -0.631957
# 1                             -0.597989
# 2                             -0.077198
#
# [3 rows x 392 columns]
